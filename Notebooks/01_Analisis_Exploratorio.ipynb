# %%
import pandas as pd

df=pd.read_csv('../data/games-1.csv')

df.head()
# Out:
#                     name  release_date  price  positive  negative   app_id  \
# 0           Train Bandit  Oct 12, 2017   0.99        53         5   655370
# 1               Henosis™  Jul 23, 2020   5.99         3         0  1355720
# 2  Two Weeks in Painland   Feb 3, 2020   0.00        50         8  1139950
# 3         Wartune Reborn  Feb 26, 2021   0.00        87        49  1469160
# 4              TD Worlds   Jan 9, 2022  10.99        21         7  1659180
#
#    min_owners  max_owners  hltb_single
# 0           0       20000          NaN
# 1           0       20000          NaN
# 2           0       20000          NaN
# 3       50000      100000          NaN
# 4           0       20000          NaN
